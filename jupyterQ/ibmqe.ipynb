# %%
import platform
if platform.system() == 'Linux':
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/ent.ipynb'
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/states.ipynb'
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/coherence.ipynb'
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/discord.ipynb'
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/nlocal.ipynb'
    # %run '/home/jonasmaziero/Dropbox/GitHub/jupyterQ/tomo.ipynb'
else:
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/ent.ipynb'
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/states.ipynb'
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/coherence.ipynb'
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/discord.ipynb'
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/nlocal.ipynb'
    # %run '/Users/jonasmaziero/Dropbox/GitHub/jupyterQ/tomo.ipynb'

# %% [markdown]
# ## Calculations related to experiments with the IBM quantum computers

# %% [markdown]
# ### Bell-diagonal states preparations
# Correlations of the experimentally prepared Werner states

# %%
evals = zeros(4,1)
rhoTb = zeros(4,4)
# Theory
N = 100
x1 = np.zeros(N+1)
x2 = np.zeros(N+1)
#x3 = np.zeros(N+1)
#x4 = np.zeros(N+1)
#x5 = np.zeros(N+1)
#x6 = np.zeros(N+1)
#x7 = np.zeros(N+1)
#x8 = np.zeros(N+1)
for j in range(0,N+1):
    x1[j] = j/N
    rho = werner(x1[j])
    #x2[j] = concurrence(rho)
    x2[j] = negativity(2,2,rho)
    #x3[j] = coh_l1(4,rho)
    #x5[j] = chsh(rho)
    #x6[j] = steering(rho)
    #x7[j] = mutual_info(2,2,rho)/2
    #x8[j] = coh_nl(2,2,rho)
#evals = zeros(3,1)
#x4 = np.zeros(N+1)
#for j in range(0,N+1):
#    x1[j] = j/N
#    rho = werner(x1[j])
#    x4[j] = hellinger(2,2,rho)
plt.plot(x1, x2, label = 'Et', color = 'blue')
#plt.plot(x1, x3, label = 'C', color = 'red')
#plt.plot(x1, x4, label = 'D', color = 'magenta')
#plt.plot(x1, x5, label = 'N', color = 'cyan')
#plt.plot(x1, x6, label = 'S', color = 'black')
#plt.plot(x1, x7, label = 'I/2', color = 'gray')
#plt.plot(x1, x8, label = 'Cnl', color = 'brown')
# Experiment
N = 15
we = np.array([0, 0.1, 0.2, 0.3, 0.32,0.34, 0.36, 0.38, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0])
Ee = np.zeros(N)
#rhoE = zeros(4,4)
for j in range(0,N):
    sj = str(j)
    path1 = '/home/jonasmaziero/Dropbox/Research/ibm/bds/'
    path2 = 'werner_qx2/dados_plot/'
    path = path1 + path2 + sj + '/'
    rhoE = tomo2qb(path)
    #Ee[j] = concurrence(rhoE)
    Ee[j] = negativity(2,2,rhoE)
plt.plot(we, Ee, label='Ee', color = 'cyan')

plt.xlabel('w')
plt.ylabel('')
plt.legend()
axes = plt.gca()
axes.set_xlim([0,1])
axes.set_ylim([0,1])
plt.show()
if platform.system() == 'Linux':
    plt.savefig('/home/jonasmaziero/Dropbox/Research/ibm/bds/calc/qcorr.eps', format='eps', dpi=100)
else:
    plt.savefig('/Users/jonasmaziero/Dropbox/Research/ibm/bds/calc/qcorr.eps', format='eps', dpi=100)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-14-ce959d9b1a41> in <module>()
#      46     rhoE = tomo2qb(path)
#      47     #Ee[j] = concurrence(rhoE)
# ---> 48     Ee[j] = negativity(2,2,rhoE)
#      49 plt.plot(we, Ee, label='Ee', color = 'cyan')
#      50
#
# <ipython-input-4-c2be7a2dfa61> in negativity(da, db, rho)
#       3     d = da*db
#       4     rhoTb = pTransposeB(da, db, rho)
# ----> 5     En = (normTr(d,rhoTb) - 1)/2
#       6     return En
#
# <ipython-input-4-2dcdfffaac9f> in normTr(d, A)
#       1 def normTr(d, A):
# ----> 2     eva = eVals(d, A)
#       3     TrNorm = 0
#       4     for j in range(0,d):
#       5         TrNorm += abs(eva[j])
#
# <ipython-input-4-e0b15551e1c2> in eVals(d, A)
#       1 # Outside this function, initialize: evals = zeros(d,1)
#       2 def eVals(d,A):
# ----> 3     eig = A.eigenvects()
#       4     ne = 0
#       5     j = 0
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in eigenvects(self, error_when_incomplete, **flags)
#    1180                                   **flags)
#    1181         ret = [(val, mult, eigenspace(val)) for val, mult in
# -> 1182                     sorted(eigenvals.items(), key=default_sort_key)]
#    1183         if primitive:
#    1184             # if the primitive flag is set, get rid of any common
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in <listcomp>(.0)
#    1179                                   error_when_incomplete=error_when_incomplete,
#    1180                                   **flags)
# -> 1181         ret = [(val, mult, eigenspace(val)) for val, mult in
#    1182                     sorted(eigenvals.items(), key=default_sort_key)]
#    1183         if primitive:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in eigenspace(eigenval)
#    1165             """Get a basis for the eigenspace for a particular eigenvalue"""
#    1166             m = mat - self.eye(mat.rows) * eigenval
# -> 1167             ret = m.nullspace()
#    1168             # the nullspace for a real eigenvalue should be
#    1169             # non-trivial.  If we didn't find an eigenvector, try once
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in nullspace(self, simplify)
#     946         """
#     947
# --> 948         reduced, pivots = self.rref(simplify=simplify)
#     949
#     950         free_vars = [i for i in range(self.cols) if i not in pivots]
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in rref(self, iszerofunc, simplify, pivots, normalize_last)
#     878         ret, pivot_cols = self._eval_rref(iszerofunc=iszerofunc,
#     879                                           simpfunc=simpfunc,
# --> 880                                           normalize_last=normalize_last)
#     881         if pivots:
#     882             ret = (ret, pivot_cols)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in _eval_rref(self, iszerofunc, simpfunc, normalize_last)
#     533         reduced, pivot_cols, swaps = self._row_reduce(iszerofunc, simpfunc,
#     534                                                       normalize_last, normalize=True,
# --> 535                                                       zero_above=True)
#     536         return reduced, pivot_cols
#     537
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in _row_reduce(self, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     649             pivot_offset, pivot_val, \
#     650             assumed_nonzero, newly_determined = _find_reasonable_pivot(
# --> 651                 get_col(piv_col)[piv_row:], iszerofunc, simpfunc)
#     652
#     653             # _find_reasonable_pivot may have simplified some things
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in _find_reasonable_pivot(col, iszerofunc, simpfunc)
#    4105         if possible_zeros[i] is not None:
#    4106             continue
# -> 4107         if x.equals(S.Zero):
#    4108             # `.iszero` may return False with
#    4109             # an implicit assumption (e.g., `x.equals(0)`
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in equals(self, other, failing_expression)
#     664         # to be zero -- we try to prove it via minimal_polynomial.
#     665         if diff.is_number:
# --> 666             approx = diff.nsimplify()
#     667             if not approx:
#     668                 # try to prove via self-consistency
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in nsimplify(self, constants, tolerance, full)
#    3099         """See the nsimplify function in sympy.simplify"""
#    3100         from sympy.simplify import nsimplify
# -> 3101         return nsimplify(self, constants, tolerance, full)
#    3102
#    3103     def separate(self, deep=False, force=False):
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/simplify/simplify.py in nsimplify(expr, constants, tolerance, full, rational, rational_conversion)
#    1209     """
#    1210     try:
# -> 1211         return sympify(as_int(expr))
#    1212     except (TypeError, ValueError):
#    1213         pass
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/compatibility.py in as_int(n)
#     330     """
#     331     try:
# --> 332         result = int(n)
#     333         if result != n:
#     334             raise TypeError
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in __int__(self)
#     206         if not self.is_number:
#     207             raise TypeError("can't convert symbols to int")
# --> 208         r = self.round(2)
#     209         if not r.is_Number:
#     210             raise TypeError("can't convert complex to int")
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# ... last 7 frames repeated, from the frame below ...
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in round(self, p)
#    3234         if not x.is_real:
#    3235             i, r = x.as_real_imag()
# -> 3236             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3237         if not x:
#    3238             return x
#
# RecursionError: maximum recursion depth exceeded
